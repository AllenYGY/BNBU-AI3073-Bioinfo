# %%
rawCounts <- read.delim("E-GEOD-50760-raw-counts.tsv") # nolint # nolint
sampleData <- read.delim("E-GEOD-50760-experiment-design.tsv") # nolint

# %%
countData <- subset(rawCounts, select= -c(Gene.Name,Gene.ID)) # nolint
rownames(countData) <- rawCounts$Gene.ID # nolint

# %%
install.packages("IRkernel")
IRkernel::installspec(user = FALSE)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# colData <- data.frame(condition=sampleData$Sample.Characteristics.biopsy.site.) # nolint
# rownames(colData) <- sampleData$Run # nolint
# Out:
# Error in `.rowNamesDF<-`(x, value = value): invalid 'row.names' length
# Traceback:
#
# 1. `row.names<-`(`*tmp*`, value = value)
# 2. `row.names<-.data.frame`(`*tmp*`, value = value)
# 3. `.rowNamesDF<-`(x, value = value)
# 4. stop("invalid 'row.names' length")
# 5. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = invokeRestart("eval_error",
#  .             cnd))
#  . }, "invalid 'row.names' length", base::quote(`.rowNamesDF<-`(x,
#  .     value = value)))

# %%
# if (!require("BiocManager", quietly = TRUE))
#     install.packages("BiocManager") # nolint

# BiocManager::install("DESeq2")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.20 (BiocManager 1.30.25), R 4.4.1 (2024-06-14)
#
# Installing package(s) 'DESeq2'
#
# also installing the dependency ‘locfit’
#
#
# Warning message in install.packages(...):
# “installation of package ‘locfit’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘DESeq2’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'curl', 'data.table', 'fs', 'future.apply', 'gtable', 'MASS',
#   'Matrix', 'nlme', 'progressr', 'ps', 'rstudioapi', 'withr'

# %%
library(DESeq2)
# Out:
# Failed to start the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
dds <- DESeqDataSetFromMatrix(countData = countData,
                              colData = colData,
                              design = ~ design)
# Out:
# Warning message in install.packages("locfit"):
# “installation of package ‘locfit’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# Error in library(locfit): there is no package called ‘locfit’
# Traceback:
#
# 1. stop(packageNotFoundError(package, lib.loc, sys.call()))

# %%
dds <- DESeq(dds)
res <- results(dds)

# %%
BiocManager::install("clusterProfiler")
library(clusterProfiler)
BiocManager::install("org.Hs.eg.db")
library(org.Hs.eg.db)

# %%
GO_result <- enrichGO(gene_id_list, 
                      OrgDb = org.Hs.eg.db,
                      ont = "ALL",
                      pvalueCutoff = 0.05,
                      pAdjustMethod = "BH",
                      KeyType = "ENSEMBL")

# %%
.libPaths()
# Out:
# [1] "/opt/homebrew/Caskroom/miniforge/base/envs/Env-R/lib/R/library"

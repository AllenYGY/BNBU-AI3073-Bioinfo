# %%
install.packages("BiocManager")
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
BiocManager::install("DESeq2")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.16 (BiocManager 1.30.25), R 4.2.3 (2023-03-15)
#
# Installing package(s) 'BiocVersion', 'DESeq2'
#
# Warning message:
# “dependencies ‘Matrix’, ‘MASS’ are not available”
# also installing the dependencies ‘sys’, ‘askpass’, ‘bit’, ‘cachem’, ‘bitops’, ‘formatR’, ‘curl’, ‘mime’, ‘openssl’, ‘bit64’, ‘blob’, ‘memoise’, ‘plogr’, ‘png’, ‘Biostrings’, ‘colorspace’, ‘RCurl’, ‘GenomeInfoDbData’, ‘zlibbioc’, ‘lambda.r’, ‘futile.options’, ‘XML’, ‘DBI’, ‘xtable’, ‘httr’, ‘RSQLite’, ‘KEGGREST’, ‘nlme’, ‘farver’, ‘labeling’, ‘munsell’, ‘R6’, ‘viridisLite’, ‘magrittr’, ‘pkgconfig’, ‘GenomeInfoDb’, ‘XVector’, ‘MatrixGenerics’, ‘DelayedArray’, ‘futile.logger’, ‘snow’, ‘codetools’, ‘BH’, ‘cpp11’, ‘lattice’, ‘annotate’, ‘AnnotationDbi’, ‘RColorBrewer’, ‘gtable’, ‘isoband’, ‘mgcv’, ‘scales’, ‘tibble’, ‘withr’, ‘S4Vectors’, ‘IRanges’, ‘GenomicRanges’, ‘SummarizedExperiment’, ‘BiocGenerics’, ‘Biobase’, ‘BiocParallel’, ‘matrixStats’, ‘locfit’, ‘geneplotter’, ‘ggplot2’, ‘Rcpp’, ‘RcppArmadillo’
#
#
# Warning message in install.packages(...):
# “installation of package ‘RcppArmadillo’ had non-zero exit status”

# %%
BiocManager::install(c("S4Vectors", "IRanges", "GenomicRanges", "SummarizedExperiment", 
                       "BiocGenerics", "Biobase", "BiocParallel", "matrixStats", "locfit", "ggplot2"))
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.16 (BiocManager 1.30.25), R 4.2.3 (2023-03-15)
#
# Warning message:
# “package(s) not installed when version(s) same as or greater than current; use
#   `force = TRUE` to re-install: 'S4Vectors' 'BiocGenerics' 'Biobase'
#   'matrixStats' 'locfit'”
# Installing package(s) 'IRanges', 'GenomicRanges', 'SummarizedExperiment',
#   'BiocParallel', 'ggplot2'
#
# Warning message:
# “dependencies ‘Matrix’, ‘MASS’ are not available”
# also installing the dependencies ‘GenomeInfoDb’, ‘XVector’, ‘DelayedArray’, ‘futile.logger’, ‘mgcv’, ‘scales’
#
#
# Warning message in install.packages(...):
# “installation of package ‘mgcv’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘DelayedArray’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘ggplot2’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘SummarizedExperiment’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'digest', 'evaluate', 'glue', 'jsonlite', 'pbdZMQ', 'uuid'
